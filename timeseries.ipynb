# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Watches Bags Accessories.csv', encoding='latin-1')
df
# Out:
#                                                   Title Rating in Stars  \
# 0     Yfashion Cartoon  Electronic  Watch Life Water...           4.6/5
# 1     100% Imported LED watch for men , boys and Kid...           4.3/5
# 2     1 Cartoon Characters Analog Wrist Watch For Ki...           4.5/5
# 3     M3 Touch LED Bracelet Digital Watch Band Good ...           4.6/5
# 4               led Watches For Boys and Girls and kids           4.4/5
# ...                                                 ...             ...
# 1073  Online Sale Black Stainless Steel Crystal Wris...           4.3/5
# 1074  Fashionable 3 Chrono Stain Less Steel Analog S...           3.8/5
# 1075  Gold Color 12 Point Diamond Studded Magnet Sta...           4.4/5
# 1076  Casual Women Romantic Starry Sky Wrist Watch L...           4.3/5
# 1077  Analog Watches For Girls Luxury Stylish Analog...           4.6/5
#
#       Rating Count Sold Count     Voucher       Delivery Currency  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1078 entries, 0 to 1077
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            1078 non-null   object
#  1   Rating in Stars  1078 non-null   object
#  2   Rating Count     1078 non-null   int64
#  3   Sold Count       1044 non-null   object
#  4   Voucher          1078 non-null   object
#  5   Delivery         1078 non-null   object
#  6   Currency         1078 non-null   object
#  7   Current Price    1078 non-null   object
#  8   Original Price   1010 non-null   object
#  9   Link             1078 non-null   object
#  10  Category         1078 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 92.8+ KB

# %%
df.isnull().sum()
# Out:
# Title                0
# Rating in Stars    105
# Rating Count         0
# Sold Count          32
# Voucher              0
# Delivery             0
# Current Price        0
# Original Price      67
# Category             0
# dtype: int64

# %% [markdown]
# ### Cleaning

# %%
df["Rating in Stars"].unique()
df['Rating in Stars'].replace(['5-Apr', '5-May','5-Mar','5-Jan' ], np.nan, inplace=True)
df['Rating in Stars'] = df['Rating in Stars'].str.replace('/5', '').astype(float)

# %%
df['Sold Count'] = df['Sold Count'].str.replace('Sold', '')
df['Sold Count'] = df['Sold Count'].str.replace('K', '000').str.strip().astype(float)

# %%
df["Current Price"] = df["Current Price"].str.replace(',', '').astype(float)

# %%
df["Original Price"] = df["Original Price"].str.replace('Rs.', '')
df["Original Price"] = df["Original Price"].str.replace(',', '').str.strip().astype(float)

# %%
df.drop(columns=["Currency", "Link"], inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Impute

# %%
group_means = df.groupby('Category')['Rating in Stars'].transform('mean')

df['Rating in Stars'].fillna(group_means, inplace=True)

# %%
group_means = df.groupby('Category')['Sold Count'].transform('mean')

df['Sold Count'].fillna(group_means, inplace=True)

# %%
group_means = df.groupby('Category')['Original Price'].transform('mean')

df['Original Price'].fillna(group_means, inplace=True)

# %% [markdown]
# ### Feature Engineering

# %%
df["Price Difference"] = df["Original Price"]-df["Current Price"]
df["Total Earning"] = df["Sold Count"]*df["Current Price"]

# %%
df
# Out:
#                                                   Title  Rating in Stars  \
# 0     Yfashion Cartoon  Electronic  Watch Life Water...              4.6
# 1     100% Imported LED watch for men , boys and Kid...              4.3
# 2     1 Cartoon Characters Analog Wrist Watch For Ki...              4.5
# 3     M3 Touch LED Bracelet Digital Watch Band Good ...              4.6
# 4               led Watches For Boys and Girls and kids              4.4
# ...                                                 ...              ...
# 1073  Online Sale Black Stainless Steel Crystal Wris...              4.3
# 1074  Fashionable 3 Chrono Stain Less Steel Analog S...              3.8
# 1075  Gold Color 12 Point Diamond Studded Magnet Sta...              4.4
# 1076  Casual Women Romantic Starry Sky Wrist Watch L...              4.3
# 1077  Analog Watches For Girls Luxury Stylish Analog...              4.6
#
#       Rating Count  Sold Count     Voucher       Delivery  Current Price  \
# ...

# %% [markdown]
# # Can not do Feature Analysis Due to unavailability of time variable !!
